# %% [markdown]
# # Vibrações Mecânicas Aula 1
# ## Professor Paulo Victor

# %%
import  numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
plt.rcParams['figure.figsize']=(6,3)
plt.rcParams['figure.dpi']=150

# %%
from ipywidgets import interact,interactive,fixed,interact_manual
import ipywidgets as widgets

# %%
t = np.linspace(0,10,1000)

# %%
def f(A,w,phi):
    plt.plot(t,A*np.sin(w*t+phi))
    plt.ylim(-10,10)
    plt.grid(True)
    plt.xlabel('tempo')
    plt.ylabel('amplitude')

# %% [markdown]
# $$ f(x) = A*sin(\omega t + \phi)$$

# %%
interact(f,A=(1,10),w=(1,10),phi=(0,2*np.pi))
# Out:
# interactive(children=(IntSlider(value=5, description='A', max=10, min=1), IntSlider(value=5, description='w', …
# <function __main__.f(A, w, phi)>

# %% [markdown]
# [Movimento oscilatório e Análise Harmônica](http://bilimneguzellan.net/fuyye-serisi/)

# %% [markdown]
# ## FFT

# %%
from scipy.fftpack import fft

# %%
n = 500
tf = 2.5
tn = np.linspace(0,tf,n)
T = tf/n
f1 = 20
f2 = 40
f3 = 80

# %%
y = np.sin(2*np.pi*f1*tn) + np.sin(2*np.pi*f2*tn + 3) + np.sin(2*np.pi*f3*tn + 1.5)

# %%
yf = fft(y)
xf = np.linspace(0,1/(2*T),n//2)

# %%
plt.figure()
plt.plot(tn,y)
plt.xlabel('Tempo [s]')
plt.ylabel('Amplitude')
plt.grid(True)
plt.show()

# %%
plt.figure()
plt.plot(xf, 2.0/n * np.abs(yf[:n//2]))
plt.title('FFT')
plt.xlabel('Frequênias Hz')
plt.grid(True)
plt.show()

# %%
import random as rd

# %%
A = np.zeros(1000)
for i in range(1,1000):
    A[i] = 5*rd.random()

# %%
plt.plot(t,A)
plt.grid(True)
plt.xlabel('tempo')
plt.ylabel('amplitude')
# Out:
# Text(0, 0.5, 'amplitude')
